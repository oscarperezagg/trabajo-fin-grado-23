# %%
from src.modules.ALGORITHM_MODULE import *

# %% [markdown]
# ## First Computation

# %%
computation.computeData()
# Out:
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 16] Comenzando el cálculo de los datos
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 83] ---> Obteniendo los stocks válidos
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 138] ---> Se han encontrado 30 stocks válidos
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 18] Obteninedo dirección de la carpeta temporal
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 44] ################ Procesando AKAM ################
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 44] ################ Procesando MSFT ################
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 44] ################ Procesando ADSK ################
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 44] ################ Procesando EQIX ################
# |     [2023-12-03 16:48:57] [INFO] [computation.py] [Line 44] ################ Procesando RMD ################
# ...
